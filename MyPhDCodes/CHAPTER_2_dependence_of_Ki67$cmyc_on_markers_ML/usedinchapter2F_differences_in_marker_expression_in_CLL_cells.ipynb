# %%
source("../R4_Batch_effect_Normalization/mass_cytometry_functions.R")

# %%
options(repr.plot.width=12, repr.plot.height=7)

# %%
needed_antibody1<- c('141Pr_INS14','142Nd_CD19','143Nd_CD5','144Nd_INS17','145Nd_INS5','146Nd_IgD',
                    '147Sm_INS19','149Sm_INS18','150Nd_INS20','151Eu_INS16','152Sm_CD21',
                    '153Eu_INS7','155Gd_CD27','158Gd_INS24','159Tb_CD22','160Gd_INS3','161Dy_INS26',
                    '162Dy_Ki67','163Dy_INS8','164Dy_INS25','165Ho_INS11','167Er_CD38','168Er_INS13',
                    '169Tm_INS4','172Yb_IgM','173Yb_INS6','174Yb_INS27','175Lu_CXCR4','176Yb_INS1')

# %%
needed_antibody1_rename<- c('KLF10','CD19','CD5','MYC','CD83','IgD','NR4A2','PPP1R15A','JUND','FOSB','CD21','RGS1','CD27','KLF6','CD22','TCL1A','DDIT3','Ki67','YPEL5','HSPA5','TXNIP','CD38','RGS2','EGR1','IgM','CD69','FOS','CXCR4','Actin')

# %%
boxplot_groupby_input_marker_of_fcs("../R4_Batch_effect_Normalization/Data/20 CLL/",
                                    #"Data/experiment_UMvsM/",
                                    #c("6th ","1st ", "3rd ", "2nd ", "5th "),
                                    c("c"),
                                    "yes",
                                    needed_antibody1, 
                                    needed_antibody1_rename,
                                    FALSE,
                                    "Mutation Status",
                                    "Median Intensity Expressions of Cell Markers and mRNAs in CLL Samples \n Using Mass Cytometry and PlayR Data: A Boxplot Analysis"
)
# Out:
# plot without title

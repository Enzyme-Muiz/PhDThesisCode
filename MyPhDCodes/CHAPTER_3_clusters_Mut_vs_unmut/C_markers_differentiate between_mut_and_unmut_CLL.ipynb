# %%
source("../R4_Batch_effect_Normalization/mass_cytometry_functions.R")

# %%
options(repr.plot.width=15, repr.plot.height=7)

# %%
needed_antibody1<- c('CD196','CD19', 'CD5',  'CD38', 'IgD', 'CD11c', 'CD43', 'CD69',
                    'CD21', 'CXCR5', 'CD62L', 'CD27', 'CD22', 'CXCR3', 'CD23', 'CD24', 'CCR7', 
                    'CD20', 'IgM', 'HLA-DR', 'CD49d', 'CXCR4')

# %%
boxplot_groupby_input_marker_of_fcs("../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/",
                                    #"Data/experiment_UMvsM/",
                                    #c("6th ","1st ", "3rd ", "2nd ", "5th "),
                                    c("_6_","_1_", "_3_", "_2_"),
                                    "yes",
                                    needed_antibody1, 
                                    TRUE,
                                    "Mutation Status",
                                    "Mutated (M) vs Unmutated (UM) CLL median intensity \nexpression by cell markers using 40 samples"
)
# Out:
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_6_110nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_6_11nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_6_12nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_6_13nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_6_14nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_6_15nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_6_16nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_6_17nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_6_18nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_6_19nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_1_110nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_1_11nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_1_12nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_1_13nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_1_14nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_1_15nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_1_16nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_1_17nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_1_18nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_1_19nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_3_110nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_3_11nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_3_12nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_3_13nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_3_14nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_3_15nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_3_16nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_3_17nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_3_18nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_3_19nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_2_110nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_2_11nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_2_12nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_2_13nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_2_14nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_2_15nonanchor1.fcs:M
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_2_16nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_2_17nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_2_18nonanchor1.fcs:UM
# Enter legend value for ../R4_Batch_effect_Normalization/Data/all_cytonorm_normalized/Batch_2_19nonanchor1.fcs:UM
# Scale for 'fill' is already present. Adding another scale for 'fill', which
# will replace the existing scale.
# plot without title
